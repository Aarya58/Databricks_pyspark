# %%
import pyspark.sql.functions as F

# %%
file_path="/FileStore/tables/yellow_tripdata_2018_01.parquet"
df=spark.read.parquet(file_path)
display(df.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>VendorID</th><th>tpep_pickup_datetime</th><th>tpep_dropoff_datetime</th><th>passenger_count</th><th>trip_distance</th><th>RatecodeID</th><th>store_and_fwd_flag</th><th>PULocationID</th><th>DOLocationID</th><th>payment_type</th><th>fare_amount</th><th>extra</th><th>mta_tax</th><th>tip_amount</th><th>tolls_amount</th><th>improvement_surcharge</th><th>total_amount</th><th>congestion_surcharge</th><th>airport_fee</th></tr></thead><tbody><tr><td>1</td><td>2018-01-01T00:21:05.000+0000</td><td>2018-01-01T00:24:23.000+0000</td><td>1</td><td>0.5</td><td>1</td><td>N</td><td>41</td><td>24</td><td>2</td><td>4.5</td><td>0.5</td><td>0.5</td><td>0.0</td><td>0.0</td><td>0.3</td><td>5.8</td><td>null</td><td>null</td></tr><tr><td>1</td><td>2018-01-01T00:44:55.000+0000</td><td>2018-01-01T01:03:05.000+0000</td><td>1</td><td>2.7</td><td>1</td><td>N</td><td>239</td><td>140</td><td>2</td><td>14.0</td><td>0.5</td><td>0.5</td><td>0.0</td><td>0.0</td><td>0.3</td><td>15.3</td><td>null</td><td>null</td></tr><tr><td>1</td><td>2018-01-01T00:08:26.000+0000</td><td>2018-01-01T00:14:21.000+0000</td><td>2</td><td>0.8</td><td>1</td><td>N</td><td>262</td><td>141</td><td>1</td><td>6.0</td><td>0.5</td><td>0.5</td><td>1.0</td><td>0.0</td><td>0.3</td><td>8.3</td><td>null</td><td>null</td></tr><tr><td>1</td><td>2018-01-01T00:20:22.000+0000</td><td>2018-01-01T00:52:51.000+0000</td><td>1</td><td>10.2</td><td>1</td><td>N</td><td>140</td><td>257</td><td>2</td><td>33.5</td><td>0.5</td><td>0.5</td><td>0.0</td><td>0.0</td><td>0.3</td><td>34.8</td><td>null</td><td>null</td></tr><tr><td>1</td><td>2018-01-01T00:09:18.000+0000</td><td>2018-01-01T00:27:06.000+0000</td><td>2</td><td>2.5</td><td>1</td><td>N</td><td>246</td><td>239</td><td>1</td><td>12.5</td><td>0.5</td><td>0.5</td><td>2.75</td><td>0.0</td><td>0.3</td><td>16.55</td><td>null</td><td>null</td></tr></tbody></table></div>

# %% [markdown]
# Query 1. - Add a column named as "Revenue" into dataframe which is the sum of the below columns 'Fare_amount','Extra','MTA_tax','Improvement_surcharge','Tip_amount','Tolls_amount','Total_amount'

# %%
df.withColumn("Revenue",
              F.col('Fare_amount')+ F.col('Extra')+F.col('MTA_tax')+F.col('Improvement_surcharge')+F.col('Tip_amount')+F.col('Tolls_amount')+F.col('Total_amount')).limit(5).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>VendorID</th><th>tpep_pickup_datetime</th><th>tpep_dropoff_datetime</th><th>passenger_count</th><th>trip_distance</th><th>RatecodeID</th><th>store_and_fwd_flag</th><th>PULocationID</th><th>DOLocationID</th><th>payment_type</th><th>fare_amount</th><th>extra</th><th>mta_tax</th><th>tip_amount</th><th>tolls_amount</th><th>improvement_surcharge</th><th>total_amount</th><th>congestion_surcharge</th><th>airport_fee</th><th>Revenue</th></tr></thead><tbody><tr><td>1</td><td>2018-01-01T00:21:05.000+0000</td><td>2018-01-01T00:24:23.000+0000</td><td>1</td><td>0.5</td><td>1</td><td>N</td><td>41</td><td>24</td><td>2</td><td>4.5</td><td>0.5</td><td>0.5</td><td>0.0</td><td>0.0</td><td>0.3</td><td>5.8</td><td>null</td><td>null</td><td>11.6</td></tr><tr><td>1</td><td>2018-01-01T00:44:55.000+0000</td><td>2018-01-01T01:03:05.000+0000</td><td>1</td><td>2.7</td><td>1</td><td>N</td><td>239</td><td>140</td><td>2</td><td>14.0</td><td>0.5</td><td>0.5</td><td>0.0</td><td>0.0</td><td>0.3</td><td>15.3</td><td>null</td><td>null</td><td>30.6</td></tr><tr><td>1</td><td>2018-01-01T00:08:26.000+0000</td><td>2018-01-01T00:14:21.000+0000</td><td>2</td><td>0.8</td><td>1</td><td>N</td><td>262</td><td>141</td><td>1</td><td>6.0</td><td>0.5</td><td>0.5</td><td>1.0</td><td>0.0</td><td>0.3</td><td>8.3</td><td>null</td><td>null</td><td>16.6</td></tr><tr><td>1</td><td>2018-01-01T00:20:22.000+0000</td><td>2018-01-01T00:52:51.000+0000</td><td>1</td><td>10.2</td><td>1</td><td>N</td><td>140</td><td>257</td><td>2</td><td>33.5</td><td>0.5</td><td>0.5</td><td>0.0</td><td>0.0</td><td>0.3</td><td>34.8</td><td>null</td><td>null</td><td>69.6</td></tr><tr><td>1</td><td>2018-01-01T00:09:18.000+0000</td><td>2018-01-01T00:27:06.000+0000</td><td>2</td><td>2.5</td><td>1</td><td>N</td><td>246</td><td>239</td><td>1</td><td>12.5</td><td>0.5</td><td>0.5</td><td>2.75</td><td>0.0</td><td>0.3</td><td>16.55</td><td>null</td><td>null</td><td>33.1</td></tr></tbody></table></div>

# %% [markdown]
# Query 2. - Increasing count of total passengers in New York City by area

# %%
df.groupby("PULocationID", "DOLocationID").sum("passenger_count").limit(5).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>PULocationID</th><th>DOLocationID</th><th>sum(passenger_count)</th></tr></thead><tbody><tr><td>79</td><td>116</td><td>580</td></tr><tr><td>246</td><td>249</td><td>5073</td></tr><tr><td>234</td><td>144</td><td>7047</td></tr><tr><td>161</td><td>193</td><td>100</td></tr><tr><td>231</td><td>261</td><td>5812</td></tr></tbody></table></div>

# %% [markdown]
# Query 3. - Realtime Average fare/total earning amount earned by 2 vendors

# %%
df.groupBy("VendorID").avg("total_amount").limit(5).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>VendorID</th><th>avg(total_amount)</th></tr></thead><tbody><tr><td>1</td><td>15.127384289902137</td></tr><tr><td>2</td><td>15.775723474073514</td></tr></tbody></table></div>

# %% [markdown]
# Query 4. - Moving Count of payments made by each payment mode

# %%
df.groupBy("payment_type").count().limit(5).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>payment_type</th><th>count</th></tr></thead><tbody><tr><td>1</td><td>6106416</td></tr><tr><td>3</td><td>43204</td></tr><tr><td>2</td><td>2599215</td></tr><tr><td>4</td><td>11852</td></tr></tbody></table></div>

# %% [markdown]
# Query 5. - Highest two gaining vendor's on a particular date with no of passenger and total distance by cab

# %%
display(df.select('VendorID', 'tpep_pickup_datetime', 'passenger_count', 'trip_distance').sort(df.trip_distance.desc()).limit(2))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>VendorID</th><th>tpep_pickup_datetime</th><th>passenger_count</th><th>trip_distance</th></tr></thead><tbody><tr><td>2</td><td>2018-01-30T11:41:02.000+0000</td><td>1</td><td>189483.84</td></tr><tr><td>1</td><td>2018-01-08T19:44:54.000+0000</td><td>0</td><td>830.8</td></tr></tbody></table></div>

# %% [markdown]
# Query 6. - Most no of passenger between a route of two location.

# %%
from pyspark.sql.functions import sum as _sum
df.groupBy('PULocationID','DOLocationID').agg(_sum('passenger_count').alias('TotalPassenger')).orderBy(F.col('TotalPassenger').desc()).limit(1).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>PULocationID</th><th>DOLocationID</th><th>TotalPassenger</th></tr></thead><tbody><tr><td>264</td><td>264</td><td>186705</td></tr></tbody></table></div>

# %% [markdown]
# Query 7. - Get top pickup locations with most passengers in last 5/10 seconds.

# %%
q7 = (df.groupBy(F.window('tpep_pickup_datetime', '5 seconds'))
      .agg(_sum('passenger_count').alias('sum_passenger'), F.count('PULocationID').alias('top_pick')))
qf = q7.orderBy(F.col('top_pick').desc())
display(qf.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>window</th><th>sum_passenger</th><th>top_pick</th></tr></thead><tbody><tr><td>List(2018-01-12T15:15:05.000+0000, 2018-01-12T15:15:10.000+0000)</td><td>84</td><td>64</td></tr><tr><td>List(2018-01-27T15:15:25.000+0000, 2018-01-27T15:15:30.000+0000)</td><td>74</td><td>64</td></tr><tr><td>List(2018-01-06T15:15:00.000+0000, 2018-01-06T15:15:05.000+0000)</td><td>71</td><td>56</td></tr><tr><td>List(2018-01-07T15:15:00.000+0000, 2018-01-07T15:15:05.000+0000)</td><td>78</td><td>54</td></tr><tr><td>List(2018-01-13T15:15:00.000+0000, 2018-01-13T15:15:05.000+0000)</td><td>74</td><td>53</td></tr></tbody></table></div>
